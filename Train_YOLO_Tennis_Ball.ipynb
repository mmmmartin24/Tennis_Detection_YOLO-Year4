# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 20.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Mengambil dataset dari RoboFlow menggunakan API key

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ec5El95rRDKbs2fQQnoQ")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 4995.41it/s]

# %% [markdown]
# Shutil adalah modul yang digunakan untuk operasi penyalinan, pemindahan, pengarsipan, dan penghapusan file dan direktori.

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %% [markdown]
# Training Dataset:
# 1. Memuat Dataset dengan membaca gambar dan anotasi yang ditentukan dalam data.yaml.
# 2. Memuat Model: Memuat arsitektur YOLOv5 besar (yolov5l6u.pt) sebagai model dasar.
# 3. Pelatihan: Melatih model selama 100 epoch menggunakan gambar dengan ukuran 640x640.
# Selama proses pelatihan, model akan belajar mengenali objek yang ditentukan.
# 4. Menyimpan Hasil: Model yang dilatih akan disimpan

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 165M/165M [00:02<00:00, 64.4MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **Hasil Model YOLO Ball Training**
#
# ![image.png](attachment:image.png)
